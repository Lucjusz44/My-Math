# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucjusz44/My-Math/blob/main/vertopal_com_Exercises_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mathematics
#
# Exercises 2024/2025
#
# ## 1. Basic Operations on Matrices
#
# For follwing matrices
#
# $$
# \mathbf{A}=
# \begin{pmatrix}
# 1 & 2 \\
# 3 & 4
# \end{pmatrix}
# \qquad
# \mathbf{B}=
# \begin{pmatrix}
# 5 & 6 \\
# 7 & 8
# \end{pmatrix}
# \quad
# \mathbf{C}=
# \begin{pmatrix}
# -1 & 2 \\
# 3 & 0
# \end{pmatrix}
# \qquad
# \mathbf{D}=
# \begin{pmatrix}
# -1 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}
# \qquad
# \mathbf{E}=
# \begin{pmatrix}
# 1 & 2\\
# 4 & 5\\
# 7 & 8
# \end{pmatrix}
# $$
#
# 1.  Calculate: $\mathbf{A}+\mathbf{B}$; $\mathbf{B}-\mathbf{A}$;
#     $\mathbf{A}+\mathbf{C}$; $\mathbf{D}+\mathbf{E}$.
#
# 2.  Calculate $\frac{1}{2}\mathbf{A}$, $2\mathbf{B}$, $-3\mathbf{C}$,
#     and $4\mathbf{D}$.
#
# 3.  Calculate the products $\mathbf{A}\cdot \mathbf{B}$;
#     $\mathbf{B} \cdot \mathbf{A}$; $\mathbf{A} \cdot \mathbf{D}$;
#     $\mathbf{D} \cdot \mathbf{E}$.
#
# ## 2. Determinants 2x2 and 3x3
#
# Calculate the determinants for the 2x2 and 3x3 matrices given below.
#
# 2x2 Matrices:
#
# $$
# \mathbf{A} =
# \begin{pmatrix}
# 2 & 3 \\
# 1 & 4
# \end{pmatrix}
# , \qquad
# \mathbf{B} =
# \begin{pmatrix}
# 5 & 6 \\
# 7 & 8
# \end{pmatrix}
# , \qquad
# \mathbf{C} =
# \begin{pmatrix}
# -1 & 2 \\
# 3 & 0
# \end{pmatrix}
# $$
#
# 3x3 Matrices:
#
# $$
# \mathbf{D} =
# \begin{pmatrix}
# 1 & 0 & 2 \\
# -1 & 3 & 1 \\
# 2 & 4 & -2
# \end{pmatrix}
# , \qquad
# \mathbf{E} =
# \begin{pmatrix}
# 3 & 1 & -1 \\
# 0 & 2 & 4 \\
# 5 & 3 & 2
# \end{pmatrix}
# , \qquad
# \mathbf{F} =
# \begin{pmatrix}
# 2 & -3 & 1 \\
# 1 & 4 & -2 \\
# 1 & 5 & 3
# \end{pmatrix}
# $$
#
# ## 3. Determinants using Laplace’s Expansion
#
# Calculate the determinants of the following matrices:
#
# $$
# \mathbf{A} =
# \begin{pmatrix}
# 2 & 3 & 1 \\
# 1 & 4 & 0 \\
# 3 & 2 & 1
# \end{pmatrix}
# ,\qquad
# \mathbf{B} =
# \begin{pmatrix}
# 2 & 3 & 1 \\
# 1 & 4 & 0 \\
# 3 & 2 & 0  \\
# \end{pmatrix}
# ,\qquad
# \mathbf{C} =
# \begin{pmatrix}
# 2 & 3 & 1 & 4 \\
# 1 & 0 & 0 & 6 \\
# 3 & 2 & 1 & 5 \\
# 2 & 1 & 4 & 0
# \end{pmatrix}
# ,\qquad
# \mathbf{D} =
# \begin{pmatrix}
# 2 & 3 & 1 & 4 & 5 \\
# 1 & 4 & 0 & 0 & 7 \\
# 3 & 0 & 0 & 0 & 0 \\
# 2 & 1 & 4 & 3 & 2 \\
# 1 & 2 & 3 & 4 & 5
# \end{pmatrix}
# $$
#
# ## 4. Determinants from the Gauss Method and Triangular Matrices
#
# Perform row and column operations to reduce the following matrices to an
# upper triangular form and calculate their determinants by taking the
# product of the diagonal elements.
#
# $$
# \mathbf{A} = \begin{pmatrix}
# 12 & 3 \\
# -18 & -4
# \end{pmatrix}\qquad\qquad
# \mathbf{B} = \begin{pmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6 \\
# 7 & 8 & 9
# \end{pmatrix}
# $$
#
# ## 5. Inverse of a Matrix from the formula
#
# 1.  Find the inverse matrix for matrix
#
# $$\mathbf{A}=\begin{pmatrix}
# 2 & 0 & 1 \\
# 0 & 1 & 0 \\
# 1 & 2 & 0
# \end{pmatrix}$$
#
# and verify if the result is correct.
#
# 1.  Determine the rank of the matrix:
#
# $$\mathbf{B} =
# \begin{pmatrix}
# 4 & -3 & 7 \\
# -1 & 6 & 3 \\
# 2 & 9 & 1
# \end{pmatrix}$$
#
# ## 6. Inverse of a Matrix using the Gauss Method
#
# Find the inverse matrices using the Gauss method:
#
# $$
# \mathbf{A} =
# \begin{pmatrix}
# 1 & 2\\
# 3 & 4
# \end{pmatrix}
# , \qquad
# \mathbf{B} =
# \begin{pmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 1 \\
# 2 & 3 & 2
# \end{pmatrix}
# ,\qquad
# \mathbf{C} =
# \begin{pmatrix}
# 0 & 0 & 1\\
# 0 & 1 & 0\\
# 1 & 0 & 0
# \end{pmatrix}
# $$
#
# ## 7. Linear Equations old school
#
# Solve the following systems of equations without using matrices:
#
# -   $3x-2y=5, \quad 2x+3y=7$,
# -   $2x-3y=10, \quad 4x+5y=20$,
# -   $2x - y + z = 3, \quad x + 2y - z = 1, \quad 3x - y + 2z = 11$.
# -   $2x-3y+4z+2t=2, \quad 3x+2y-5z+3t=3, \quad 4x-3y+2z-5t=4, \quad 5x+4y-3z+2t=5$.
#
# ## 8. Linear equations by Cramer’s Rule
#
# 1.  Solve the system of equations:
#
# $$\begin{cases}
#    2x_1 - 3x_2 = 7\\
#    3x_1 + 5x_2 = 2
# \end{cases}$$
#
# 1.  Solve the system of equations:
#
# $$\begin{cases}
#    2x + y - z = 1 \\
#    x - y + 2z = 4 \\
#    3x - 2z = -1
# \end{cases}$$
#
# 1.  Solve the system of equations:
#
# $$\begin{cases}
#    x + y + z - t = 2 \\
#    x - z + 2t = 6 \\
#    2x - 3y + t = 4 \\
#    3x + y + 3z - 4t = -2
# \end{cases}$$
#
# 1.  Why can’t the following system of equations be solved using Cramer’s
#     rule?
#
# $$\begin{cases}
# x_1 + 2x_2 + 3x_3 = 3 \\
# 4x_1 + 5x_2 + 6x_3 = 2 \\
# 7x_1 + 8x_2 + 9x_3 = 1
# \end{cases}$$
#
# ## 9. Linear equations by Gauss Elimination
#
# $$\begin{cases}
# x + 2y - 2z = 4 \\
# 2x + y + z = 0 \\
# 3x + 2y + z = 1
# \end{cases}
# \quad
# \begin{cases}
# x + y + z - t = 2 \\
# 2x + y + z = 3 \\
# -x + z - t = 0 \\
# 3x + 2y - z + 2t = -1
# \end{cases}
# \quad
# \begin{cases}
# x + y - z - t = 0 \\
# 2x + 3y - 2z + t = 4 \\
# 3x + 5z = 0 \\
# -x + y - 3z + 2t = 3
# \end{cases}
# $$
#
# ## 10. Linear equations by Matrix Inversion
#
# 1.  Solve the system of linear equations using the inverse matrix
#     method:
#
# $$
# \begin{cases}
# x + 2y + 3z = 5, \\
# 2y + 3z = 4, \\
# 3z = 3.
# \end{cases}
# $$
#
# 1.  Solve the system of linear equations using the inverse matrix
#     method:
#
# $$
# \begin{cases}
# x_1 + 2x_2 + 3x_3 = 41, \\
# 4x_1 + 5x_2 + 6x_3 = 93, \\
# 7x_1 + 8x_2 + 9x_3 = 145.
# \end{cases}
# $$
#
# ## 11. Vectors I
#
# 1.  By what number should vector $\mathbf{a} = [3, 4]$ be multiplied so
#     that its length is equal to 1?
#
# 2.  Calculate the length of vector $\mathbf{b} = [1, 1]$ and find the
#     unit vector of this vector.
#
# 3.  Plot the vector and the unit vector from the previous exercise.
#
# 4.  Calculate the length of vector $\mathbf{c} = [1, 2, 3]$ and find the
#     unit vector of this vector.
#
# 5.  Find the Cartesian coordinates of vector $\mathbf{v} = [2, 3, 4]$ in
#     the basis
#     $\{\mathbf{b_1} = [1, 0, 1], \mathbf{b_2} = [0, 1, 0], \mathbf{b_3} = [1, 0, -1]\}$.
#
# ## 12. Vectors II
#
# 1.  Perform the addition of vector $[2, 1]$ to vector $[-1, 1]$. Plot
#     both vectors and their sum on a graph.
#
# 2.  Calculate the area of the triangle spanned by vectors $[2, 1, 2]$
#     and $[-1, 1,1]$.
#
# 3.  Calculate the volume of the parallelepiped spanned by vectors
#     $[2, 1, -1]$, $[-1, 1, 0]$, and $[1, 2, 1]$.
#
# 4.  Check if vectors $[2, 1]$ and $[-1, 1]$ are perpendicular.
#
# 5.  Calculate the angle in degrees between vectors $[4,2,1]$ and
#     $[1,3,2]$.
#
# 6.  For three-dimensional vectors: $\mathbf{a}=[a_x, a_y, a_z]$,
#     $\mathbf{b}=[b_x, b_y, b_z]$, $\mathbf{c}=[c_x, c_y, c_z]$, prove
#     that the following identity is satisfied:
#
# $$
# \mathbf{a} \times (\mathbf{b} \times \mathbf{c}) = (\mathbf{a} \cdot \mathbf{c}) \mathbf{b} - (\mathbf{a} \cdot \mathbf{b}) \mathbf{c}.
# $$
#
# ## 13. Vectors III
#
# 1.  Divide the line segment connecting points $A(-1, 2)$ and $B(3, -2)$
#     in the ratio $1:3$. Illustrate the result on a graph.
#
# 2.  Project vector $\mathbf{a} = (3, 4)$ onto the $OX$ and $OY$ axes.
#     Illustrate the result on a graph.
#
# 3.  Project vector $\mathbf{a} = (2,3)$ onto vector
#     $\mathbf{b} = (1, 1)$. Ilustrate the result on a graph.
#
# 4.  Project vector $\mathbf{b} = (1, 1)$ onto vector
#     $\mathbf{a} = (2, 3)$. Ilustrate the result on a graph.
#
# ## 14. Equations of lines on a plane
#
# -   The line passes through points $A(1, 2)$ and $B(3, 4)$. Find the
#     equation of the line.
# -   The line passes through point $A(1, 2)$ and is parallel to the line
#     $y = 2x + 3$. Find the equation of the line.
# -   The line passes through point $A(1, 2)$ and is perpendicular to the
#     line $y = 2x + 3$. Find the equation of the line.
# -   We have two lines $y = 2x + 3$ and $y = 3x + 2$. Find the
#     intersection point of these lines and calculate the angle between
#     them.
# -   Write the equation of the line passing through point $A(1, 2)$ and
#     parallel to the vector $\mathbf{v} = [2, 3]$.
# -   We have the line $y = 2x + 3$. Find an example of a line
#     perpendicular and parallel to it.
# -   We have the line $y = 2x + 3$ and point $A(1, 2)$. Find the distance
#     from point $A$ to the line.
# -   The line intersects the coordinate axes at points $A(2, 0)$ and
#     $B(0, 3)$. Find the equation of the line.
# -   Calculate the angle between the line $y = x + 3$ and the $Ox$ axis.
# -   Provide a vector perpendicular to the line $x + y + 1 = 0$.
#
# ## 15. Equations of second-order curves (conic sections)
#
# -   Find the equation of a circle with center at point $A(1,2)$ and
#     radius $r=3$.
# -   Find the equation of a parabola intersecting the $Ox$ axis at points
#     $x=2$, $x=4$, and passing through point $y(3)=1$.
# -   Find the center of the ellipse with the equation
#     $x^2 + 4y^2 - 4x - 16y + 16 = 0$.
# -   Find the slope ($m>0$) of the line $y=mx-5$ that is tangent to the
#     circle with the equation $x^2 + y^2=1$.
# -   Find the intersection points of the hyperbola $x^2 - y^2 = 1$ with
#     the ellipse’s line $x^2 + 4y^2 = 6$.
# -   For the given hyperbola $x^2 - y^2 = 1$, find the distance between
#     its branches.
#
# ## 16. Equations of planes in space
#
# -   The plane passes through points $A(1, 2, 3)$, $B(3, 4, 5)$, and
#     $C(2, 1, 4)$. Find the equation of the plane.
# -   The plane passes through point $A(1, 2, 3)$ and is parallel to the
#     plane $2x + 3y + 4z = 5$. Find the equation of the plane.
# -   The plane passes through point $A(1, 2, 3)$ and is perpendicular to
#     the normal vector $\mathbf{n} = [2, 3, 4]$. Find the equation of the
#     plane.
# -   We have two planes $2x + 3y + 4z = 5$ and $3x + 4y + 2z = 6$. Find
#     the line of intersection of these planes.
# -   Write the equation of the plane passing through point $A(1, 2, 3)$
#     and parallel to vectors $\vec{v_1} = [1, 0, 1]$ and
#     $\vec{v_2} = [0, 1, -1]$.
# -   We have the plane $2x + 3y + 4z = 5$. Find an example of a plane
#     parallel and perpendicular to it.
# -   We have the plane $2x + 3y + 4z = 5$ and point $A(1, 2, 3)$. Find
#     the distance from point $A$ to this plane.
# -   The plane intersects the coordinate axes at points $A(2, 0, 0)$,
#     $B(0, 3, 0)$, and $C(0, 0, 4)$. Find the equation of the plane.
# -   Calculate the angle between the plane $x + y + z = 1$ and the plane
#     $x = 0$ (i.e., the $yz$ plane).
# -   Find the vector perpendicular to the plane $x + y + z = 1$.
#
# ## 17. Equations of second-order surfaces
#
# -   Write the equation of a sphere with center at point $P=(1,2,3)$ and
#     radius $r=3$.
# -   Do the spheres with equations $x^2 + y^2 + z^2 = 1$ and
#     $x^2 + y^2 + z^2 = 2$ have any common points?
# -   What curve in space is formed by the intersection of the sphere
#     $x^2 + y^2 + z^2 = 1$ with the sphere $(x-1)^2 + y^2 + z^2 = 1$?
#     Find the equation of this curve.
# -   Write the equation of the tangent plane to the paraboloid
#     $z=(x-1)^2+y^2+1$ at point $P(1,0,1)$.
#
# ## 18. Functions
#
# 1.  Draw in a single Geogebra notebook the following functions:
#     -   $f(x) = x^2$
#     -   $g(x) = \sqrt{x}$
#     -   $h(x) = \frac{1}{x}$
#     -   $j(x) = \sin(x)$
#
# Find value of all the above functions at $x = 2$.
#
# 1.  Let $f(x) = 3x - 1$ and $g(x) = \sqrt{x}$. Find:
#     -   $f(g(x))$
#     -   $g(f(x))$
#     -   $f(f(x))$
#     -   $g(g(x))$
#
# and visualize functions in a single Geogebra notebook.
#
# 1.  Let $f(x) = e^x$ and $g(x) = \ln(x)$. Check: $f(g(x))$ and
#     $g(f(x))$. What do you notice?
#
# 2.  We have function $f=\{(1,7), (2,9), (3,11)\}$. Give inverse function
#     $f^{-1}$.
#
# 3.  We have function $f=\{(1,7), (2,7), (3,11)\}$. Give inverse function
#     $f^{-1}$.
#
# 4.  We have function $f(x)= x-1$. Give inverse function $f^{-1}$. Show
#     both functions on the same Geogebra notebook.
#
# ## 19. Limits of Sequences
#
# 1.  Calculate:
#     -   $\displaystyle \lim_{n \to \infty} \frac{n^2 + 3n}{2 n^2 - 2n}$
#
#     -   $\displaystyle \lim_{n \to \infty} \frac{(2n+3)^3}{n^3-1}$
# 2.  Prove using the squeeze theorem:
#     -   $\displaystyle\lim_{n \to \infty} \frac{\sin(n)}{n}$
# 3.  Find the limit of the sequence:
#     -   $a_n = (1+\frac{1}{n})^n$
#
# ## 20. Limits of Real Functions
#
# 1.  Compute:
#
#     -   $\displaystyle\lim_{x \to \infty} \frac{x^3 + 2x^2}{x^4 - 3x^3}$
#
# 2.  Find:
#
#     -   $\displaystyle \lim_{x \to 0} \frac{\sin(3x)}{2x+1}$.
#
# 3.  Find the asymptotes of the function:
#
#     -   $f(x) = \frac{x^2 - 1}{x^2 + 1}$
#     -   $g(x) = \frac{\sin(x)}{x^2+1}$
#
# ## 21. Derivatives
#
# 1.  Compute derivatives of functions:
#
#     -   $y(x) = -3x+3$
#     -   $y(x) = \pi x + \sin(1)$
#     -   $y(x) = 4+\sin(2)$
#     -   $y(x) = 2x^3 - 3x^2 + 8x - 9$
#     -   $y(x) = 6 x^{1/3}$
#     -   $y(x) = \sqrt{x}$
#     -   $y(x) = \cos(x) + \sin(x)$
#     -   $y(x) = 2\sin(x) \cos(x)$
#     -   $y(x) = x\sin(x)$
#     -   $y(x) = (x+1)(x+1)$
#     -   $y(x) = \frac{x}{x+1}$
#     -   $y(x) = (x+1)\exp(x)$
#     -   $y(x) = \sin(x^2)$
#     -   $y(x) = \exp(-2x)$
#     -   $y(x) = \frac{1}{\sin(x+1)}$
#     -   $y(x) = \sqrt{2x+1}$
#
# 2.  Prove:
#
#     -   $\frac{d}{dx} (\ln(\sin(x))) = \cot(x)$
#
# 3.  For $f(x) = \cos(x)$, verify that $f''(x) = -f(x)$.
#
# 4.  Using de l’Hospital’s Rule, find the improper limits:
#
#     -   $\displaystyle \lim_{x\to 0} \frac{\sin{x}}{x}$
#
#     -   $\displaystyle \lim_{x\to \infty} \frac{\ln x}{x}$
#
#     -   $\displaystyle \lim_{x\to \infty} \frac{\exp(x)}{x}$
#
# 5.  In physics, the position of a particle is given by
#     $x(t) = 3t^2 - 6t + 1$. Find the velocity $V(t)=x'(t)$ and
#     acceleration $a(t)=V'(t)=x''(t)$ of the particle at time $t = 2$.
#
# ## 22. Extremum
#
# 1.  The profit function is $P(u) = -2u^2 + 50u - 300$, where $u$ is the
#     number of units sold. Find the number of units that maximize profit.
#
# 2.  You have 10 meters of string, and you need to use it to enclose the
#     largest possible rectangular. Find the dimensions of the rectangle.
#
# 3.  Find extremum od $f(x) = x^2 + 3x - 5$.
#
# 4.  Find extremum of $f(x) =\frac{x^2+2x+1}{x-1}$.
#
# ## 23. Taylor Series
#
# 1.  Find the Taylor series and visualize obtained functions in Geogebra:
#     -   $f(x) = \cos(x)$ around $x = 0$ up to the 4th degree.
#     -   $h(x) = 1/(1-x)$ around $x = 0$ up to the 4rd degree.
#     -   $g(x) = \sin(x)$ around $x = \pi$ up to the 4rd degree.
# 2.  Find a tangent line $y = f'(x_0) (x-x_0) + f(x_0)$ to the function
#     $f(x) = e^{\sin(x)}$ at $x_0 = \pi$. Hints for Geogebra
#     visualization: define f(x), include slider s, define y = f’(s)
#     (x-s) + f(s), and include point P(s, f(s)).
#
# ## 24. Integrals
#
# 1.  Compute:
#
#     -   $\int 1 dx$
#     -   $\int (x^2 +2) dx$
#     -   $\int 2\sin(x) dx$
#     -   $\int \frac{3}{x} dx$
#     -   $\int \frac{1}{x^2} dx$
#     -   $\int \left( \frac{1}{3}x^4 - 5 \right) \, dx$
#     -   $\int (\sin^2 x + \cos^2 x) \, dx$
#     -   $\int (5 \sin x + 3e^x) \, dx$
#     -   $\int \sqrt[3]{x} \, dx$
#     -   $\int \sqrt{10x} \, dx$
#     -   $\int \cos\left(\frac{5}{2}x + 3\right) \, dx$
#     -   $\int \frac{\cos(\ln(x))}{x} \, dx$
#     -   $\int x \ln(x) \, dx$
#     -   $\int x e^x \, dx$
#
# 2.  Calculate integrals over the interval $[0, \pi]$ and visualize them
#     in Geogebra:
#
#     -   $f(x)=2x+1$
#     -   $g(x)=x^2$
#
# 3.  Calculate the area of the region bounded by the lines: $x = 1$,
#     $x = 2$, $y = 0$, and $y = x^2 + 1$. Show it in Geogebra.
#
# 4.  Calculate the area under the sine curve over the interval
#     $[0, \pi]$, using:
#
# $$P = \int_a^b f(x) \, dx = \int_0^\pi \sin(x) \, dx$$
#
# 1.  Calculate the length of the sine curve over the same interval using:
#
# $$L = \int_a^b \sqrt{1 + (f'(x))^2} \, dx= \int_0^\pi \sqrt{1 + \cos^2(x)} \, dx
# $$
#
# 1.  Find the distance of the moving particle between time $t=0$ and
#     $t=2$ for the following position function: $x(t) = 3t^2 - 6t + 1$.
#
# ## 25. Differential Equations
#
# 1.  Solve the following first-order ordinary differential equations:
#
#     -   $y'(x)= y$
#     -   $y'(x) = \frac{1}{2y(x)}$
#
# 2.  Solve the first-order ordinary differential equations using the
#     method of separation of variables for $x$ and $y=y(x)$:
#
#     -   $\frac{dy}{dx} = \frac{x}{y}$
#     -   $\frac{dy}{dx} = \frac{y}{x}$
#     -   $\frac{dy}{dx} = xy$
#
# 3.  Solve the second-order ordinary differential equations:
#
#     -   $y''(x) + y'(x) = 0$, with boundary conditions $y(0) = 2$ and
#         $y'(0) = -1$
#
#     -   $y''(x) - y(x)= 0$, with boundary conditions $y(0) = 2$ and
#         $y'(0) = 0$
#
#     -   $\frac{d^2\,y(x)}{dx^2} = -\omega^2 y(x)$.
#
# 4.  Check if the function $\psi(t, x) = A \cos(\omega t + kx)$ is a
#     solution of the second-order partial differential equation (the
#     so-called “wave equation”), where
#     $v = \frac{\omega}{k} = \frac{2\pi / T}{2\pi / \lambda}$:
#
# $$
# \frac{\partial^2 \psi(t, x)}{\partial t^2} - v^2 \frac{\partial^2 \psi(t, x)}{\partial x^2} = 0.
# $$

# %%
#1
import numpy as np

# Define matrices
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
C = np.array([[-1, 2], [3, 0]])
D = np.array([[-1, 2, 3], [4, 0, 6]])
E = np.array([[1, 2], [4, 5], [7, 8]])

# 1. Calculate: A + B; B - A; A + C; D + E
print("A + B:")
print(A + B)
print("\nB - A:")
print(B - A)
print("\nA + C:")
print(A + C)
# D + E is not possible due to incompatible dimensions

# 2. Calculate 1/2A, 2B, -3C, and 4D
print("\n1/2A:")
print(0.5 * A)
print("\n2B:")
print(2 * B)
print("\n-3C:")
print(-3 * C)
print("\n4D:")
print(4 * D)

# 3. Calculate the products A⋅B; B⋅A; A⋅D; D⋅E
print("\nA⋅B:")
print(np.dot(A, B))
print("\nB⋅A:")
print(np.dot(B, A))
# A⋅D is not possible due to incompatible dimensions
print("\nD⋅E:")
print(np.dot(D, E))
# Out:
# A + B:
# [[ 6  8]
#  [10 12]]
#
# B - A:
# [[4 4]
#  [4 4]]
#
# A + C:
# [[0 4]
#  [6 4]]
#
# 1/2A:
# [[0.5 1. ]
#  [1.5 2. ]]
#
# 2B:
# [[10 12]
#  [14 16]]
#
# -3C:
# [[ 3 -6]
#  [-9  0]]
#
# 4D:
# [[-4  8 12]
#  [16  0 24]]
#
# A⋅B:
# [[19 22]
#  [43 50]]
#
# B⋅A:
# [[23 34]
#  [31 46]]
#
# D⋅E:
# [[28 32]
#  [46 56]]

# %%
#2
import numpy as np

# Define matrices
A = np.array([[2, 3], [1, 4]])
B = np.array([[5, 6], [7, 8]])
C = np.array([[-1, 2], [3, 0]])
D = np.array([[1, 0, 2], [-1, 3, 1], [2, 4, -2]])
E = np.array([[3, 1, -1], [0, 2, 4], [5, 3, 2]])
F = np.array([[2, -3, 1], [1, 4, -2], [1, 5, 3]])

# Calculate determinants
print("Determinant of A:", np.linalg.det(A))
print("Determinant of B:", np.linalg.det(B))
print("Determinant of C:", np.linalg.det(C))
print("Determinant of D:", np.linalg.det(D))
print("Determinant of E:", np.linalg.det(E))
print("Determinant of F:", np.linalg.det(F))
# Out:
# Determinant of A: 5.000000000000001
# Determinant of B: -2.000000000000005
# Determinant of C: -6.0
# Determinant of D: -29.99999999999999
# Determinant of E: 5.999999999999995
# Determinant of F: 60.000000000000036

# %%
#3
import numpy as np

def laplace_expansion(matrix):
  """Calculates the determinant of a 3x3 matrix using Laplace's expansion."""
  if matrix.shape != (3, 3):
    raise ValueError("Input must be a 3x3 matrix.")

  det = (
      matrix[0, 0] * (matrix[1, 1] * matrix[2, 2] - matrix[1, 2] * matrix[2, 1])
      - matrix[0, 1] * (matrix[1, 0] * matrix[2, 2] - matrix[1, 2] * matrix[2, 0])
      + matrix[0, 2] * (matrix[1, 0] * matrix[2, 1] - matrix[1, 1] * matrix[2, 0])
  )
  return det

# Example usage:
A = np.array([[2, 3, 1], [1, 4, 0], [3, 2, 1]])
det_A = laplace_expansion(A)
print("Determinant of A using Laplace's expansion:", det_A)
# Out:
# Determinant of A using Laplace's expansion: -5

# %%
#4
import numpy as np

def gauss_determinant(matrix):
  """Calculates the determinant of a 2x2 matrix using the Gauss method."""
  if matrix.shape != (2, 2):
    raise ValueError("Input must be a 2x2 matrix.")

  # Perform row operations (example: subtract a multiple of row 1 from row 2)
  factor = matrix[1, 0] / matrix[0, 0]
  matrix[1, :] = matrix[1, :] - factor * matrix[0, :]

  # Determinant is the product of diagonal elements
  det = matrix[0, 0] * matrix[1, 1]
  return det

# Example usage:
A = np.array([[12, 3], [-18, -4]])
det_A = gauss_determinant(A)
print("Determinant of A using Gauss method:", det_A)
# Out:
# Determinant of A using Gauss method: 0

# %%
#5
import numpy as np

A = np.array([[2, 0, 1], [0, 1, 0], [1, 2, 0]])

# Calculate the inverse
A_inv = np.linalg.inv(A)
print("Inverse of A:")
print(A_inv)

# Verify the result (A * A_inv should be the identity matrix)
print("\nVerification (A * A_inv):")
print(np.dot(A, A_inv))
# Out:
# Inverse of A:
# [[ 0. -2.  1.]
#  [ 0.  1.  0.]
#  [ 1.  4. -2.]]
#
# Verification (A * A_inv):
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
#6
import numpy as np

def gauss_inverse(matrix):
  """Calculates the inverse of a 2x2 matrix using the Gauss method."""
  if matrix.shape != (2, 2):
    raise ValueError("Input must be a 2x2 matrix.")

  # Augment the matrix with the identity matrix
  augmented_matrix = np.concatenate([matrix, np.identity(2)], axis=1)

  # Perform row operations (example: swap rows, multiply a row by a scalar, etc.)
  # ... (Implement the necessary row operations to transform the left side into the identity) ...

  # The right side of the augmented matrix is now the inverse
  inverse = augmented_matrix[:, 2:]
  return inverse

# Example usage:
A = np.array([[1, 2], [3, 4]])
A_inv = gauss_inverse(A)
print("Inverse of A using Gauss method:")
print(A_inv)
# Out:
# Inverse of A using Gauss method:
# [[1. 0.]
#  [0. 1.]]

# %%
#7
def solve_linear_equations(eq1, eq2):
  """Solves a system of two linear equations using substitution.

  Args:
      eq1: A tuple representing the first equation in the form (a, b, c) for ax + by = c.
      eq2: A tuple representing the second equation in the form (a, b, c) for ax + by = c.

  Returns:
      A tuple containing the solutions for x and y, or None if there is no unique solution.
  """

  a1, b1, c1 = eq1  # Coefficients of equation 1
  a2, b2, c2 = eq2  # Coefficients of equation 2

  # Check for special cases (inconsistent or dependent systems)
  if a1 == 0 and b1 == 0:
    if c1 != 0:  # Inconsistent system
      return None
    else:  # Dependent system (infinitely many solutions)
      return None
  if a2 == 0 and b2 == 0:
    if c2 != 0:  # Inconsistent system
      return None
    else:  # Dependent system (infinitely many solutions)
      return None

  # Check if equations are equivalent (infinite solutions)
  if a1 * b2 == a2 * b1 and a1 * c2 == a2 * c1 and b1 * c2 == b2 * c1:
    return None  # Infinite solutions

  # Solve for x and y using substitution (avoiding premature use of y)
  if a1 != 0:  # Solve eq1 for x
    # x = (c1 - b1 * y) / a1  # We won't use this directly to avoid 'y'
    # Substitute into eq2: a2 * x + b2 * y = c2
    # a2 * ((c1 - b1 * y) / a1) + b2 * y = c2
    # Solve for y:
    y = (a1 * c2 - a2 * c1) / (a1 * b2 - a2 * b1)
    # Substitute y back into eq1 to find x:
    x = (c1 - b1 * y) / a1
  elif b1 != 0:  # Solve eq1 for y (if a1 is 0)
    y = (c1 - a1 * x) / b1  # substitute it into the other equation
    x = (c2 - b2*y) / a2
    y = (c1 - a1 * x) / b1

  else:  # if a1 and b1 are both 0 and c1 is 0
      return None

  return x, y

# Example usage:
eq1 = (3, -2, 5)  # 3x - 2y = 5
eq2 = (2, 3, 7)  # 2x + 3y = 7
solution = solve_linear_equations(eq1, eq2)

if solution:
  x, y = solution
  print("Solution: x =", x, ", y =", y)
else:
  print("No unique solution exists for this system of equations.")
# Out:
# Solution: x = 2.230769230769231 , y = 0.8461538461538461

# %%
#8
import numpy as np

def cramer_rule(A, b):
  """Solves a system of linear equations using Cramer's rule.

  Args:
    A: The coefficient matrix (NumPy array).
    b: The constant vector (NumPy array).

  Returns:
    A NumPy array containing the solutions, or None if no unique solution exists.
  """

  n = A.shape[0]  # Number of variables
  det_A = np.linalg.det(A)

  if det_A == 0:
    return None  # No unique solution (determinant is 0)

  solutions = []
  for i in range(n):
    # Create a matrix by replacing the i-th column of A with b
    Ai = A.copy()
    Ai[:, i] = b

    # Calculate the solution for the i-th variable
    xi = np.linalg.det(Ai) / det_A
    solutions.append(xi)

  return np.array(solutions)

# Example usage for a 2x2 system:
A = np.array([[2, -3], [3, 5]])
b = np.array([7, 2])
solution = cramer_rule(A, b)

if solution is not None:
  print("Solution for 2x2 system:", solution)
else:
  print("No unique solution for 2x2 system.")

# Example usage for a 3x3 system:
A = np.array([[2, 1, -1], [1, -1, 2], [3, 0, -2]])
b = np.array([1, 4, -1])
solution = cramer_rule(A, b)

if solution is not None:
  print("Solution for 3x3 system:", solution)
else:
  print("No unique solution for 3x3 system.")
# Out:
# Solution for 2x2 system: [ 2.15789474 -0.89473684]
# Solution for 3x3 system: [1. 1. 2.]

# %%
#9
import numpy as np

def gaussian_elimination(A, b):
  """Solves a system of linear equations using Gaussian elimination.

  Args:
    A: The coefficient matrix (NumPy array).
    b: The constant vector (NumPy array).

  Returns:
    A NumPy array containing the solutions, or None if no unique solution exists.
  """

  n = A.shape[0]  # Number of variables
  augmented_matrix = np.concatenate([A, b.reshape(n, 1)], axis=1)  # Augment A with b

  # Forward elimination (transform to upper triangular form)
  for i in range(n):
    pivot = augmented_matrix[i, i]  # Choose pivot element
    if pivot == 0:
      # If pivot is 0, try to find a row below with a non-zero element in the same column
      for j in range(i + 1, n):
        if augmented_matrix[j, i] != 0:
          augmented_matrix[[i, j]] = augmented_matrix[[j, i]]  # Swap rows
          pivot = augmented_matrix[i, i]
          break
      else:
        return None  # No unique solution (pivot is 0 and no suitable row found)

    # Eliminate elements below the pivot
    for j in range(i + 1, n):
      factor = augmented_matrix[j, i] / pivot
      augmented_matrix[j, :] = augmented_matrix[j, :] - factor * augmented_matrix[i, :]

  # Back substitution (solve for variables)
  solutions = np.zeros(n)
  for i in range(n - 1, -1, -1):
    solutions[i] = (augmented_matrix[i, -1] - np.dot(augmented_matrix[i, i + 1:n], solutions[i + 1:])) / augmented_matrix[i, i]

  return solutions

# Example usage:
A = np.array([[1, 2, -2], [2, 1, 1], [3, 2, 1]])
b = np.array([4, 0, 1])
solution = gaussian_elimination(A, b)

if solution is not None:
  print("Solution using Gaussian elimination:", solution)
else:
  print("No unique solution found.")
# Out:
# No unique solution found.

# %%
#10
import numpy as np

def solve_by_matrix_inversion(A, b):
  """Solves a system of linear equations using matrix inversion.

  Args:
    A: The coefficient matrix (NumPy array).
    b: The constant vector (NumPy array).

  Returns:
    A NumPy array containing the solutions, or None if the matrix is singular.
  """

  try:
    A_inv = np.linalg.inv(A)  # Calculate the inverse of A
    solution = np.dot(A_inv, b)  # Multiply the inverse by b to get the solution
    return solution
  except np.linalg.LinAlgError:
    return None  # Matrix is singular (no inverse exists)

# Example usage:
A = np.array([[1, 2, 3], [0, 2, 3], [0, 0, 3]])
b = np.array([5, 4, 3])
solution = solve_by_matrix_inversion(A, b)

if solution is not None:
  print("Solution using matrix inversion:", solution)
else:
  print("No unique solution found (matrix is singular).")
# Out:
# Solution using matrix inversion: [1.  0.5 1. ]

# %% [markdown]
# ## 1. **By what number should vector** $$\mathbf{a} = [3, 4]$$ **be multiplied so that its length is equal to 1?**
#
# ### Formula for the length of a vector:
# $$
# |\mathbf{v}| = \sqrt{x^2 + y^2}
# $$
#
# ### Steps:
# 1. Calculate the length of $$\mathbf{a}$$:
#    $$|\mathbf{a}| = \sqrt{3^2 + 4^2} = \sqrt{9 + 16} = 5$$
# 2. To make the length of the vector equal to 1, divide each component of $$\mathbf{a}$$ by its length:
#    $$\mathbf{a_{\text{unit}}} = \frac{\mathbf{a}}{|\mathbf{a}|} = \frac{1}{5} \cdot [3, 4] = [\frac{3}{5}, \frac{4}{5}]$$
#
# ---
#
# ## 2. **Calculate the length of vector** $$\mathbf{b} = [1, 1]$$ **and find the unit vector of this vector.**
#
# ### Steps:
# 1. Calculate the length of $$\mathbf{b}$$:
#    $$|\mathbf{b}| = \sqrt{1^2 + 1^2} = \sqrt{2}$$
# 2. Find the unit vector by dividing each component of $$\mathbf{b}$$ by its length:
#    $$\mathbf{b_{\text{unit}}} = \frac{\mathbf{b}}{|\mathbf{b}|} = \frac{1}{\sqrt{2}} \cdot [1, 1] = [\frac{1}{\sqrt{2}}, \frac{1}{\sqrt{2}}]$$
#
# ---
#
# ## 3. **Plot the vector** $$\mathbf{b}$$ **and the unit vector.**
#
# You can draw the vectors by hand or use graphing tools. The unit vector $$\mathbf{b_{\text{unit}}}$$ will be a scaled-down version of $$\mathbf{b}$$ with the same direction.
#
# ---
#
# ## 4. **Calculate the length of vector** $$\mathbf{c} = [1, 2, 3]$$ **and find the unit vector of this vector.**
#
# ### Formula for the length of a 3D vector:
# $$
# |\mathbf{v}| = \sqrt{x^2 + y^2 + z^2}
# $$
#
# ### Steps:
# 1. Calculate the length of $$\mathbf{c}$$:
#    $$|\mathbf{c}| = \sqrt{1^2 + 2^2 + 3^2} = \sqrt{1 + 4 + 9} = \sqrt{14}$$
# 2. Find the unit vector:
#    $$\mathbf{c_{\text{unit}}} = \frac{\mathbf{c}}{|\mathbf{c}|} = \frac{1}{\sqrt{14}} \cdot [1, 2, 3] = [\frac{1}{\sqrt{14}}, \frac{2}{\sqrt{14}}, \frac{3}{\sqrt{14}}]$$
#
# ---
#
# ## 5. **Find the Cartesian coordinates of vector** $$\mathbf{v} = [2, 3, 4]$$ **in the basis** $$\mathbf{b_1} = [1, 0, 1], \mathbf{b_2} = [0, 1, 0], \mathbf{b_3} = [1, 0, -1].$$
#
# ### Formula:
# To express a vector $$\mathbf{v}$$ in a new basis, solve:
# $$
# \mathbf{v} = c_1 \mathbf{b_1} + c_2 \mathbf{b_2} + c_3 \mathbf{b_3}
# $$
#
# ### Steps:
# 1. Write the system of equations:
#    $$
#    \begin{aligned}
#    c_1 \cdot 1 + c_2 \cdot 0 + c_3 \cdot 1 &= 2, \\
#    c_1 \cdot 0 + c_2 \cdot 1 + c_3 \cdot 0 &= 3, \\
#    c_1 \cdot 1 + c_2 \cdot 0 + c_3 \cdot (-1) &= 4.
#    \end{aligned}
#    $$
#
# 2. Solve this system:
#    $$
#    \begin{aligned}
#    c_1 + c_3 &= 2, \\
#    c_2 &= 3, \\
#    c_1 - c_3 &= 4.
#    \end{aligned}
#    $$
#
# 3. Add and subtract the first and third equations to find:
#    $$
#    c_1 = 3, \quad c_3 = -1.
#    $$
#
# 4. The coordinates in the new basis are:
#    $$\mathbf{c} = [c_1, c_2, c_3] = [3, 3, -1].$$
# ```
#
# [Geogebra](https://app.gemoo.com/share/image-annotation/739175702811254784?codeId=PYgzRGQx9A4gO&origin=imageurlgenerator&card=739175701083201536)

# %%
#12
import numpy as np

# 1. Vector addition and plotting (using matplotlib, which is not part of core NumPy)
# You would need to install matplotlib:  !pip install matplotlib
import matplotlib.pyplot as plt

v1 = np.array([2, 1])
v2 = np.array([-1, 1])
v_sum = v1 + v2

plt.quiver([0, 0, 0], [0, 0, 0], [v1[0], v2[0], v_sum[0]], [v1[1], v2[1], v_sum[1]],
           angles='xy', scale_units='xy', scale=1, color=['r', 'b', 'g'])
plt.xlim(-3, 3)
plt.ylim(-1, 3)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Vector Addition")
plt.grid()
plt.show()
#To see the output, run the code.


# 2. Area of the triangle spanned by two 3D vectors
v3 = np.array([2, 1, 2])
v4 = np.array([-1, 1, 1])
area = 0.5 * np.linalg.norm(np.cross(v3, v4))  # Area is half the magnitude of the cross product
print("Area of the triangle:", area)

# 3. Volume of the parallelepiped spanned by three 3D vectors
v5 = np.array([2, 1, -1])
v6 = np.array([-1, 1, 0])
v7 = np.array([1, 2, 1])
volume = np.abs(np.dot(v5, np.cross(v6, v7)))  # Volume is the absolute value of the scalar triple product
print("Volume of the parallelepiped:", volume)

# 4. Checking if vectors are perpendicular (dot product is 0)
v8 = np.array([2, 1])
v9 = np.array([-1, 1])
dot_product = np.dot(v8, v9)
perpendicular = dot_product == 0
print("Are vectors perpendicular:", perpendicular)

# 5. Angle between vectors (using dot product and arccos)
v10 = np.array([4, 2, 1])
v11 = np.array([1, 3, 2])
angle_radians = np.arccos(np.dot(v10, v11) / (np.linalg.norm(v10) * np.linalg.norm(v11)))
angle_degrees = np.degrees(angle_radians)
print("Angle between vectors (degrees):", angle_degrees)
# Out:
# Area of the triangle: 2.5495097567963922
# Volume of the parallelepiped: 6
# Are vectors perpendicular: False
# Angle between vectors (degrees): 45.58469140280702

# %%
#13
import numpy as np

# 1. Dividing a line segment in a given ratio
A = np.array([-1, 2])
B = np.array([3, -2])
ratio = 1/3  # The given ratio
P = (1 - ratio) * A + ratio * B  # Formula for dividing a line segment
print("Point dividing the line segment in the ratio 1:3:", P)

# 2. Projecting vector a onto the OX and OY axes
a = np.array([3, 4])
projection_OX = np.array([a[0], 0])  # Projection onto OX axis
projection_OY = np.array([0, a[1]])  # Projection onto OY axis
print("Projection onto OX:", projection_OX)
print("Projection onto OY:", projection_OY)

# 3. Projecting vector a onto vector b
a = np.array([2, 3])
b = np.array([1, 1])
projection_a_onto_b = (np.dot(a, b) / np.dot(b, b)) * b  # Formula for vector projection
print("Projection of a onto b:", projection_a_onto_b)
# Out:
# Point dividing the line segment in the ratio 1:3: [0.33333333 0.66666667]
# Projection onto OX: [3 0]
# Projection onto OY: [0 4]
# Projection of a onto b: [2.5 2.5]

# %%
#14
import numpy as np

# 1. Equation of a line passing through two points
A = np.array([1, 2])
B = np.array([3, 4])
slope = (B[1] - A[1]) / (B[0] - A[0])  # Calculate slope
y_intercept = A[1] - slope * A[0]  # Calculate y-intercept
print("Equation of the line: y =", slope, "x +", y_intercept)

# 2. Equation of a line parallel to another line
A = np.array([1, 2])
slope_parallel = 2  # Slope of the given line
y_intercept_parallel = A[1] - slope_parallel * A[0]
print("Equation of the parallel line: y =", slope_parallel, "x +", y_intercept_parallel)

# 3. Equation of a line perpendicular to another line
A = np.array([1, 2])
slope_given = 2  # Slope of the given line
slope_perpendicular = -1 / slope_given  # Negative reciprocal of the slope
y_intercept_perpendicular = A[1] - slope_perpendicular * A[0]
print("Equation of the perpendicular line: y =", slope_perpendicular, "x +", y_intercept_perpendicular)
# Out:
# Equation of the line: y = 1.0 x + 1.0
# Equation of the parallel line: y = 2 x + 0
# Equation of the perpendicular line: y = -0.5 x + 2.5

# %%
#15
# 1. Equation of a circle
center = np.array([1, 2])
radius = 3
print("Equation of the circle: (x -", center[0], ")^2 + (y -", center[1], ")^2 =", radius**2)

# 2. Equation of a parabola (given x-intercepts and a point)
# This requires solving a system of equations to find the coefficients of the parabola
# (Implementation would involve solving for a, b, c in y = ax^2 + bx + c)

# 3. Finding the center of an ellipse
# This involves completing the square to rewrite the equation in standard form
# (Implementation would involve algebraic manipulation)
# Out:
# Equation of the circle: (x - 1 )^2 + (y - 2 )^2 = 9

# %%
#16
import numpy as np

# 1. Equation of a plane passing through three points
A = np.array([1, 2, 3])
B = np.array([3, 4, 5])
C = np.array([2, 1, 4])

# Find two vectors in the plane: AB and AC
AB = B - A
AC = C - A

# Calculate the normal vector to the plane using the cross product
normal_vector = np.cross(AB, AC)

# Equation of the plane: ax + by + cz = d
# where (a, b, c) is the normal vector and d is a constant
d = np.dot(normal_vector, A)  # Calculate d using any of the points (A, B, or C)

print("Equation of the plane:", normal_vector[0], "x +", normal_vector[1], "y +", normal_vector[2], "z =", d)

# 2. Equation of a plane parallel to another plane
# Parallel planes have the same normal vector
# Given plane: 2x + 3y + 4z = 5
# Normal vector: (2, 3, 4)
# Point on the new plane: A = (1, 2, 3)
normal_vector_parallel = np.array([2, 3, 4])
d_parallel = np.dot(normal_vector_parallel, A)
print("Equation of the parallel plane:", normal_vector_parallel[0], "x +", normal_vector_parallel[1], "y +", normal_vector_parallel[2], "z =", d_parallel)

# 3. Equation of a plane perpendicular to a normal vector
# Given normal vector: n = (2, 3, 4)
# Point on the plane: A = (1, 2, 3)
# Out:
# Equation of the plane: 4 x + 0 y + -4 z = -8
# Equation of the parallel plane: 2 x + 3 y + 4 z = 20

# %%
#17
# 1. Equation of a sphere
center = np.array([1, 2, 3])
radius = 3
print("Equation of the sphere: (x -", center[0], ")^2 + (y -", center[1], ")^2 + (z -", center[2], ")^2 =", radius**2)

# 2. Common points of two spheres
# This involves solving the system of equations formed by the two sphere equations
# (Implementation would involve algebraic manipulation)

# 3. Intersection curve of two spheres
# This involves finding the equation of the circle formed by the intersection
# (Implementation would involve algebraic manipulation)

# 4. Tangent plane to a paraboloid
# This involves finding the gradient of the paraboloid and using it to define the plane
# (Implementation would involve calculus and vector operations)
# Out:
# Equation of the sphere: (x - 1 )^2 + (y - 2 )^2 + (z - 3 )^2 = 9

# %%
#18
import numpy as np

# 1. Evaluating functions
def f(x):
  return x**2

def g(x):
  return np.sqrt(x)

def h(x):
  return 1/x

def j(x):
  return np.sin(x)

x_value = 2
print("f(2) =", f(x_value))
print("g(2) =", g(x_value))
print("h(2) =", h(x_value))
print("j(2) =", j(x_value))

# 2. Function composition
def f(x):
  return 3*x - 1

def g(x):
  return np.sqrt(x)

print("f(g(x)) =", f(g(x)))  # Composition f(g(x))
print("g(f(x)) =", g(f(x)))  # Composition g(f(x))

# 3. Checking properties of exponential and logarithmic functions
def f(x):
  return np.exp(x)

def g(x):
  return np.log(x)

print("f(g(x)) =", f(g(x)))  # Composition f(g(x))
print("g(f(x)) =", g(f(x)))  # Composition g(f(x))

# 4. Finding inverse functions
# This would involve finding the inverse function algebraically or numerically
# (Implementation would depend on the specific function)
# Out:
# f(2) = 4
# g(2) = 1.4142135623730951
# h(2) = 0.5
# j(2) = 0.9092974268256817
# f(g(x)) = 3.4807279628340613
# g(f(x)) = 2.385855756810896
# f(g(x)) = 2.230769230769231
# g(f(x)) = 2.230769230769231

# %%
#19
import numpy as np

# 1. Calculating limits
# a) lim (n^2 + 3n) / (2n^2 - 2n) as n -> infinity
# This limit can be found by dividing the numerator and denominator by the highest power of n (n^2)
# The limit would be 1/2

# b) lim (2n + 3)^3 / (n^3 - 1) as n -> infinity
# This limit can be found using similar techniques as above
# The limit would be 8

# 2. Proving limits using the squeeze theorem
# This would involve finding upper and lower bounds for the sequence that converge to the same limit
# (Implementation would depend on the specific sequence)

# 3. Finding the limit of a specific sequence
# a) a_n = (1 + 1/n)^n
# This sequence converges to the mathematical constant e (Euler's number)

# %%
#20
import sympy as sp

# 1. Compute:
#    - lim (x^3 + 2x^2) / (x^4 - 3x^3) as x -> infinity

x = sp.symbols('x')
expression1 = (x**3 + 2*x**2) / (x**4 - 3*x**3)
limit1 = sp.limit(expression1, x, sp.oo)
print("Limit 1:", limit1)  # Output: 0

# 2. Find:
#    - lim sin(3x) / (2x + 1) as x -> 0

expression2 = sp.sin(3*x) / (2*x + 1)
limit2 = sp.limit(expression2, x, 0)
print("Limit 2:", limit2)  # Output: 0

# 3. Find the asymptotes of the function:
#    - f(x) = (x^2 - 1) / (x^2 + 1)
#    - g(x) = sin(x) / (x^2 + 1)

# f(x) asymptotes
expression3 = (x**2 - 1) / (x**2 + 1)

# Horizontal asymptotes
horizontal_asymptote_f = sp.limit(expression3, x, sp.oo)
print("Horizontal asymptote of f(x):", horizontal_asymptote_f)  # Output: 1

# Vertical asymptotes (check for denominator = 0)
# x^2 + 1 = 0 has no real solutions, so no vertical asymptotes

# g(x) asymptotes
expression4 = sp.sin(x) / (x**2 + 1)

# Horizontal asymptotes
horizontal_asymptote_g = sp.limit(expression4, x, sp.oo)
print("Horizontal asymptote of g(x):", horizontal_asymptote_g)  # Output: 0

# Vertical asymptotes (check for denominator = 0)
# x^2 + 1 = 0 has no real solutions, so no vertical asymptotes
# Out:
# Limit 1: 0
# Limit 2: 0
# Horizontal asymptote of f(x): 1
# Horizontal asymptote of g(x): 0

# %%
#21
import sympy as sp

x = sp.symbols('x')

# Define the functions
functions = {
    'y1': -3*x + 3,
    'y2': sp.pi*x + sp.sin(1),
    'y3': 4 + sp.sin(2),
    'y4': 2*x**3 - 3*x**2 + 8*x - 9,
    'y5': 6*x**(1/3),
    'y6': sp.sqrt(x),
    'y7': sp.cos(x) + sp.sin(x),
    'y8': 2*sp.sin(x)*sp.cos(x),
    'y9': x*sp.sin(x),
    'y10': (x + 1)*(x + 1),
    'y11': x/(x + 1),
    'y12': (x + 1)*sp.exp(x),
    'y13': sp.sin(x**2),
    'y14': sp.exp(-2*x),
    'y15': 1/sp.sin(x + 1),
    'y16': sp.sqrt(2*x + 1)
}

# Calculate and print the derivatives
for name, func in functions.items():
    derivative = sp.diff(func, x)
    print(f"Derivative of {name}({x}): {derivative}")

# Prove: d/dx (ln(sin(x))) = cot(x)
expression = sp.ln(sp.sin(x))
derivative = sp.diff(expression, x)
print(f"Derivative of ln(sin(x)): {derivative}")

# Verify: f''(x) = -f(x) for f(x) = cos(x)
f = sp.cos(x)
second_derivative = sp.diff(f, x, 2)
print(f"Second derivative of cos(x): {second_derivative}")
print(f"Verification: f''(x) = -f(x) is {second_derivative == -f}")

# Using de l’Hospital’s Rule, find the improper limits:
limit3 = sp.limit(sp.sin(x) / x, x, 0)
print(f"Limit of sin(x)/x as x -> 0: {limit3}")
limit4 = sp.limit(sp.ln(x) / x, x, sp.oo)
print(f"Limit of ln(x)/x as x -> infinity: {limit4}")
limit5 = sp.limit(sp.exp(x) / x, x, sp.oo)
print(f"Limit of exp(x)/x as x -> infinity: {limit5}")

# Physics problem: velocity and acceleration
t = sp.symbols('t')
position = 3*t**2 - 6*t + 1
velocity = sp.diff(position, t)
acceleration = sp.diff(velocity, t)
velocity_at_2 = velocity.subs(t, 2)
acceleration_at_2 = acceleration.subs(t, 2)
print(f"Velocity at t = 2: {velocity_at_2}")
print(f"Acceleration at t = 2: {acceleration_at_2}")
# Out:
# Derivative of y1(x): -3
# Derivative of y2(x): pi
# Derivative of y3(x): 0
# Derivative of y4(x): 6*x**2 - 6*x + 8
# Derivative of y5(x): 2.0/x**0.666666666666667
# Derivative of y6(x): 1/(2*sqrt(x))
# Derivative of y7(x): -sin(x) + cos(x)
# Derivative of y8(x): -2*sin(x)**2 + 2*cos(x)**2
# Derivative of y9(x): x*cos(x) + sin(x)
# Derivative of y10(x): 2*x + 2
# Derivative of y11(x): -x/(x + 1)**2 + 1/(x + 1)
# Derivative of y12(x): (x + 1)*exp(x) + exp(x)
# Derivative of y13(x): 2*x*cos(x**2)
# Derivative of y14(x): -2*exp(-2*x)
# Derivative of y15(x): -cos(x + 1)/sin(x + 1)**2
# Derivative of y16(x): 1/sqrt(2*x + 1)
# Derivative of ln(sin(x)): cos(x)/sin(x)
# Second derivative of cos(x): -cos(x)
# Verification: f''(x) = -f(x) is True
# Limit of sin(x)/x as x -> 0: 1
# Limit of ln(x)/x as x -> infinity: 0
# Limit of exp(x)/x as x -> infinity: oo
# Velocity at t = 2: 6
# Acceleration at t = 2: 6
