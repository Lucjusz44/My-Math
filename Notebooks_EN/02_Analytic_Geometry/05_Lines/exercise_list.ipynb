# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucjusz44/My-Math/blob/main/Notebooks_EN/02_Analytic_Geometry/05_Lines/exercise_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tasks related to equations of lines on a plane
#
# **Visualize each task.** - Python, GeoGebra, Wolfram Alpha, …
#
# -   The line passes through points $A(1, 2)$ and $B(3, 4)$. Find the
#     equation of the line.
# -   The line passes through point $A(1, 2)$ and is parallel to the line
#     $y = 2x + 3$. Find the equation of the line.
# -   The line passes through point $A(1, 2)$ and is perpendicular to the
#     line $y = 2x + 3$. Find the equation of the line.
# -   We have two lines $y = 2x + 3$ and $y = 3x + 2$. Find the
#     intersection point of these lines and calculate the angle between
#     them.
# -   Write the equation of the line passing through point $A(1, 2)$ and
#     parallel to the vector $\vec{v} = [2, 3]$.
# -   We have the line $y = 2x + 3$. Find an example of a line
#     perpendicular and parallel to it.
# -   We have the line $y = 2x + 3$ and point $A(1, 2)$. Find the distance
#     from point $A$ to the line.
# -   The line intersects the coordinate axes at points $A(2, 0)$ and
#     $B(0, 3)$. Find the equation of the line.
# -   Calculate the angle between the line $y = x + 3$ and the $Ox$ axis.
# -   Provide a vector perpendicular to the line $x + y + 1 = 0$.

# %% [markdown]
# ### Problem: Find the Equation of the Line Passing Through Points \( A(1, 2) \) and \( B(3, 4) \)
#
# ---
#
# ### Step-by-Step Solution:
#
# #### Step 1: Find the Slope (\( m \)) of the Line
# The slope of a line passing through two points \( A(x_1, y_1) \) and \( B(x_2, y_2) \) is given by:
# $$
# m = \frac{y_2 - y_1}{x_2 - x_1}
# $$
#
# Substitute the coordinates of \( A(1, 2) \) and \( B(3, 4) \):
# $$
# m = \frac{4 - 2}{3 - 1} = \frac{2}{2} = 1
# $$
#
# ---
#
# #### Step 2: Use the Point-Slope Form to Find the Equation
# The point-slope form of a line is:
# $$
# y - y_1 = m(x - x_1)
# $$
#
# Using point \( A(1, 2) \) and slope \( m = 1 \):
# $$
# y - 2 = 1(x - 1)
# $$
#
# Simplify:
# $$
# y - 2 = x - 1
# $$
# $$
# y = x - 1 + 2
# $$
# $$
# y = x + 1
# $$
#
# ---
#
# #### Step 3: Write the Final Equation
# The equation of the line in slope-intercept form is:
# $$
# \boxed{y = x + 1}
# $$
#
# ---
#
# ### Verification:
# To verify, check that both points \( A(1, 2) \) and \( B(3, 4) \) satisfy the equation \( y = x + 1 \):
#
# 1. For \( A(1, 2) \):
#    $$
#    y = 1 + 1 = 2
#    $$
#    This matches the \( y \)-coordinate of \( A \).
#
# 2. For \( B(3, 4) \):
#    $$
#    y = 3 + 1 = 4
#    $$
#    This matches the \( y \)-coordinate of \( B \).
#
# ---
#
# ### Key Takeaways:
# 1. The slope \( m \) of a line passing through two points \( A(x_1, y_1) \) and \( B(x_2, y_2) \) is:
#    $$
#    m = \frac{y_2 - y_1}{x_2 - x_1}
#    $$
# 2. The equation of the line can be written using the point-slope form:
#    $$
#    y - y_1 = m(x - x_1)
#    $$
# 3. Simplify the equation to slope-intercept form \( y = mx + b \).
#
# ---
# [GeoGebra](https://app.gemoo.com/share/image-annotation/739262940001738752?codeId=DG2wRxxeRERyE&origin=imageurlgenerator&card=739262938370154496)

# %% [markdown]
# ### Problem: Find the Equation of the Line Passing Through Point \( A(1, 2) \) and Parallel to the Line \( y = 2x + 3 \)
#
# ---
#
# ### Step-by-Step Solution:
#
# #### Step 1: Identify the Slope of the Given Line
# The given line is:
# \[
# y = 2x + 3
# \]
#
# This is in slope-intercept form \( y = mx + b \), where:
# - \( m \) is the slope,
# - \( b \) is the y-intercept.
#
# From the equation, the slope \( m \) is:
# \[
# m = 2
# \]
#
# ---
#
# #### Step 2: Use the Slope of the Parallel Line
# Parallel lines have the **same slope**. Therefore, the slope of the desired line is also:
# \[
# m = 2
# \]
#
# ---
#
# #### Step 3: Use the Point-Slope Form to Find the Equation
# The point-slope form of a line is:
# \[
# y - y_1 = m(x - x_1)
# \]
#
# Using point \( A(1, 2) \) and slope \( m = 2 \):
# \[
# y - 2 = 2(x - 1)
# \]
#
# Simplify:
# \[
# y - 2 = 2x - 2
# \]
# \[
# y = 2x - 2 + 2
# \]
# \[
# y = 2x
# \]
#
# ---
#
# #### Step 4: Write the Final Equation
# The equation of the line in slope-intercept form is:
# \[
# \boxed{y = 2x}
# \]
#
# ---
#
# ### Verification:
# To verify, check that:
# 1. The line passes through point \( A(1, 2) \):
#    \[
#    y = 2(1) = 2
#    \]
#    This matches the \( y \)-coordinate of \( A \).
#
# 2. The slope of the line is \( 2 \), which matches the slope of the given line \( y = 2x + 3 \).
#
# ---
#
# ### Key Takeaways:
# 1. Parallel lines have the **same slope**.
# 2. Use the point-slope form to find the equation of a line:
#    \[
#    y - y_1 = m(x - x_1)
#    \]
# 3. Simplify the equation to slope-intercept form \( y = mx + b \).
#
# ---
#
# [GeoGebra](https://app.gemoo.com/share/image-annotation/739266734567612416?codeId=DWBzAaGX9QOWg&origin=imageurlgenerator&card=739266732982165504)

# %% [markdown]
# ### Step 1: Understand the Problem
# We need to find the equation of a line that:
# 1. Passes through the point \( A(1, 2) \).
# 2. Is **perpendicular** to the line \( y = 2x + 3 \).
#
# ---
#
# ### Step 2: What Does "Perpendicular" Mean?
# Two lines are **perpendicular** if they meet at a right angle (90 degrees). For their slopes:
# - If the slope of one line is \( m \), the slope of the perpendicular line is the **negative reciprocal** of \( m \), which is \( -\frac{1}{m} \).
#
# ---
#
# ### Step 3: Find the Slope of the Given Line
# The given line is \( y = 2x + 3 \). This is in the form \( y = mx + b \), where:
# - \( m \) is the slope.
# - \( b \) is the y-intercept.
#
# So, the slope of the given line is:
# $$
# m_1 = 2
# $$
#
# ---
#
# ### Step 4: Find the Slope of the Perpendicular Line
# The slope of the perpendicular line is the **negative reciprocal** of \( m_1 \). So:
# $$
# m_2 = -\frac{1}{m_1} = -\frac{1}{2}
# $$
#
# ---
#
# ### Step 5: Use the Point-Slope Form to Find the Equation
# We know:
# - The slope of the new line is \( m_2 = -\frac{1}{2} \).
# - The line passes through the point \( A(1, 2) \).
#
# The **point-slope form** of a line is:
# $$
# y - y_1 = m(x - x_1)
# $$
# Where:
# - \( (x_1, y_1) \) is a point on the line.
# - \( m \) is the slope.
#
# Substitute \( m = -\frac{1}{2} \) and \( (x_1, y_1) = (1, 2) \):
# $$
# y - 2 = -\frac{1}{2}(x - 1)
# $$
#
# ---
#
# ### Step 6: Simplify the Equation
# Let’s simplify the equation step by step:
# 1. Distribute \( -\frac{1}{2} \):
#    $$
#    y - 2 = -\frac{1}{2}x + \frac{1}{2}
#    $$
#
# 2. Add \( 2 \) to both sides to solve for \( y \):
#    $$
#    y = -\frac{1}{2}x + \frac{1}{2} + 2
#    $$
#
# 3. Combine the constants:
#    $$
#    y = -\frac{1}{2}x + \frac{5}{2}
#    $$
#
# ---
#
# ### Final Answer:
# The equation of the line is:
# $$
# y = -\frac{1}{2}x + \frac{5}{2}
# $$
#
# This will:
# 1. Plot the original line \( y = 2x + 3 \).
# 2. Plot the perpendicular line passing through \( A(1, 2) \).
#
# ---
#
# ### Key Notes:
# 1. **Slope of a line**: It tells us how steep the line is. For \( y = mx + b \), \( m \) is the slope.
# 2. **Negative reciprocal**: To find the slope of a perpendicular line, flip the slope and change its sign.
# 3. **Point-slope form**: \( y - y_1 = m(x - x_1) \) is used when you know a point and the slope.
#
# [GeoGebra](https://app.gemoo.com/share/image-annotation/739268118083944448?codeId=DWBzAq4xx5gAe&origin=imageurlgenerator&card=739268116448165888)

# %% [markdown]
# ### Step 1: Find Where the Two Lines Meet
# We have two lines:
# 1. \( y = 2x + 3 \)
# 2. \( y = 3x + 2 \)
#
# To find where they meet:
# - Set the two equations equal to each other:
#   \[
#   2x + 3 = 3x + 2
#   \]
# - Solve for \( x \):
#   \[
#   2x + 3 = 3x + 2 \\
#   3 - 2 = 3x - 2x \\
#   1 = x
#   \]
#   So, \( x = 1 \).
#
# - Now, find \( y \) by plugging \( x = 1 \) into one of the equations. Let’s use \( y = 2x + 3 \):
#   \[
#   y = 2(1) + 3 = 2 + 3 = 5
#   \]
#
# So, the two lines meet at the point:
# \[
# \boxed{(1, 5)}
# \]
#
# ---
#
# ### Step 2: Find the Angle Between the Two Lines
# The angle between two lines depends on how steep they are (their slopes). Here’s how to find it:
#
# 1. **Find the steepness (slope) of each line**:
#    - The first line is \( y = 2x + 3 \). Its slope is **2**. This means for every step you go to the right, the line goes up by 2 steps.
#    - The second line is \( y = 3x + 2 \). Its slope is **3**. This means for every step you go to the right, the line goes up by 3 steps.
#
# 2. **Use the formula to find the angle**:
#    - The formula for the angle between two lines is based on their slopes. Here’s how it works:
#      - Subtract the smaller slope from the bigger slope: \( 3 - 2 = 1 \).
#      - Multiply the two slopes: \( 2 \times 3 = 6 \).
#      - Add 1 to the result: \( 1 + 6 = 7 \).
#      - Divide the first result by the second result: \( \frac{1}{7} \).
#      - Take the **arctangent** of this value (use a calculator for this step). This gives you the angle in radians.
#      - Convert the angle from radians to degrees (most calculators can do this directly).
#
# ##To find the angle between the two lines:
# 1. Take the number 0.142
# 2. Use a calculator to find the **arctangent** of 0.142.
# 3. The result is approximately **8.13 degrees**.
#
# ---
#
# So, the angle between the two lines is about:**8.13 degrees**.
#
# [GeoGebra](https://app.gemoo.com/share/image-annotation/739273579654955008?codeId=M0jbVVaVayAjq&origin=imageurlgenerator&card=739273578056925184)

# %% [markdown]
# Got it, bro! No boxes, no fancy stuff, just plain and simple. Here’s the **super simple version**:
#
# ---
#
# ### Step 1: Understand the Problem
# - We have a point \( A(1, 2) \).
# - The line we want is parallel to the vector \( \vec{v} = [2, 3] \).
#
# ---
#
# ### Step 2: Find the Slope
# The vector \( \vec{v} = [2, 3] \) tells us:
# - For every 2 steps to the right, the line goes up by 3 steps.
#
# So, the **slope (\( m \))** of the line is:
# \[
# m = 3/2
# \]
#
# ---
#
# ### Step 3: Use the Point-Slope Form
# The **point-slope form** of a line is:
# \[
# y - y_1 = m(x - x_1)
# \]
# Where:
# - \( (x_1, y_1) \) is the point \( A(1, 2) \).
# - \( m = 3/2 \) is the slope.
#
# Substitute the values:
# \[
# y - 2 = (3/2)(x - 1)
# \]
#
# ---
#
# ### Step 4: Simplify the Equation
# Expand and simplify:
# \[
# y - 2 = (3/2)x - 3/2
# \]
# Add 2 to both sides:
# \[
# y = (3/2)x - 3/2 + 2
# \]
# Combine the constants:
# \[
# y = (3/2)x + 1/2
# \]
#
# ---
#
# ### Final Answer:
# The equation of the line is:
# \[
# y = (3/2)x + 1/2
# \]
#
#
# This will:
# 1. Plot the point \( A(1, 2) \).
# 2. Draw the vector \( \vec{v} = [2, 3] \).
# 3. Plot the line \( y = (3/2)x + 1/2 \), which passes through \( A \) and is parallel to \( \vec{v} \).
#
# [GeoGebra](https://app.gemoo.com/share/image-annotation/739276769238573056?codeId=Pa0mGdZZdrqyN&origin=imageurlgenerator&card=739276767598612480)

# %% [markdown]
# Ah, I see what you’re saying, bro! The **quad** and **\text{or just}** stuff is just LaTeX formatting, and it’s totally unnecessary. Let’s remove all that and make it **super simple** and clean. Here’s the fixed version:
#
# ---
#
# ### Task: Find a Line Parallel and Perpendicular to \( y = 2x + 3 \)
#
# ---
#
# ### Step 1: Understand the Given Line
# The line we have is:
# \[
# y = 2x + 3
# \]
# - The **slope** of this line is \( 2 \). This means for every step you go to the right, the line goes up by 2 steps.
# - The **y-intercept** is \( 3 \). This is where the line crosses the y-axis.
#
# ---
#
# ### Step 2: Find a Parallel Line
# **Parallel lines** have the **same slope** but different y-intercepts. So, to find a line parallel to \( y = 2x + 3 \):
# - Keep the slope the same: \( 2 \).
# - Change the y-intercept to any other number (let’s use \( 0 \) for simplicity).
#
# The equation of the parallel line is:
# \[
# y = 2x
# \]
#
# ---
#
# ### Step 3: Find a Perpendicular Line
# **Perpendicular lines** have slopes that are **negative reciprocals** of each other. This means:
# - Flip the slope \( 2 \) to \( 1/2 \).
# - Change the sign to negative: \( -1/2 \).
#
# So, the slope of the perpendicular line is \( -1/2 \). Now, choose a y-intercept (let’s use \( 0 \) again for simplicity).
#
# The equation of the perpendicular line is:
# \[
# y = -1/2x
# \]
#
# ---
#
# ### Step 4: Visualize the Lines
# - The **original line** \( y = 2x + 3 \) goes up steeply.
# - The **parallel line** \( y = 2x \) goes up just as steeply but starts at the origin.
# - The **perpendicular line** \( y = -1/2x \) goes down gently and crosses the original line at a right angle.
#
# ---
#
# ### Final Answer:
# 1. **Parallel Line**:
#    \[
#    y = 2x
#    \]
# 2. **Perpendicular Line**:
#    \[
#    y = -1/2x
#    \]
#
# ---
#
# This will:
# 1. Plot the original line \( y = 2x + 3 \).
# 2. Plot the parallel line \( y = 2x \).
# 3. Plot the perpendicular line \( y = -1/2x \).
#
# ---
# [GeoGebra](https://app.gemoo.com/share/image-annotation/739313734302437376?codeId=DWB6Z3oyzRKd4&origin=imageurlgenerator&card=739313732184313856)

# %% [markdown]
# ## **Finding the Distance from a Point to a Line**
# We’re figuring out how far the point \( A(1, 2) \) is from the line \( y = 2x + 3 \).
#
# ---
#
# ### **Steps for Beginners**
#
# 1. **Use the distance rule**
# There’s a rule that says we can find the distance by doing the following:
# - Take the numbers from the line and the point.
# - Plug them into this rule:
# \[
# Distance = \frac{\text{Absolute value of } (a \cdot x_1 + b \cdot y_1 + c)}{\text{Square root of } (a^2 + b^2)}
# \]
#
#
# 2. **Rewrite the line**
# The line \( y = 2x + 3 \) can be changed into this form:
# \[
# 2x - y + 3 = 0
# \]
# Now we know:
# - \( a = 2 \)
# - \( b = -1 \)
# - \( c = 3 \)
#
# 3. **Add the point into the rule**
# Our point is \( (1, 2) \):
# - \( x_1 = 1 \)
# - \( y_1 = 2 \)
#
# Plug everything in:
# \[
# Top part = |(2 \cdot 1) + (-1 \cdot 2) + 3|
# \]
#
# Do the math:
# \[
# 2 - 2 + 3 = 3
# \]
#
# The top part is 3.
#
# 4. **Do the bottom part**
# The bottom part is:
# \[
# {Square root of } (a^2 + b^2)
# \]
# \[
# {Square root of } (2^2 + (-1)^2)
# \]
#
# Do the math:
# \[
# 4 + 1 = 5
# \]
# So the bottom part is the square root of 5.
#
# 5. **Find the distance**
# Now divide:
# \[
# Distance = 3 \divided by the square root of 5.
# \]
# If you want a rounded answer:
# \[
# text{Distance} \approx 1.34
# \]
#
# ---
#
# ### **Final Answer**
# The distance from \( A(1, 2) \) to the line \( y = 2x + 3 \) is about:
# \[
# \1.34
# \]
#
# [GeoGebra](https://app.gemoo.com/share/image-annotation/739318850497679360?codeId=DWB6JYxbgjzd4&origin=imageurlgenerator&card=739318848291475456)

# %% [markdown]
# ## **Finding the Equation of a Line Through Two Points**
#
# We need to find the equation of the line passing through \( A(2, 0) \) and \( B(0, 3) \).
#
# ---
#
# ### **Steps for Beginners**
#
# ### 1. **Understand the general line equation**
# The equation of a line is:
# \[
# y = mx + b
# \]
# Where:
# - \( m \) is the slope (how steep the line is).
# - \( b \) is the \( y \)-intercept (where the line crosses the \( y \)-axis).
#
# ---
#
# ### 2. **Find the slope \( m \)**
# The slope \( m \) is found using the two points \( A(2, 0) \) and \( B(0, 3) \):
# \[
# m = \frac{\text{change in } y}{\text{change in } x} = \frac{y_2 - y_1}{x_2 - x_1}
# \]
# Substitute the points \( A(2, 0) \) (\( x_1 = 2, y_1 = 0 \)) and \( B(0, 3) \) (\( x_2 = 0, y_2 = 3 \)):
# \[
# m = \frac{3 - 0}{0 - 2} = \frac{3}{-2} = -1.5
# \]
#
# So, the slope \( m = -1.5 \).
#
# ---
#
# ### 3. **Write the line equation using \( m \) and \( b \)**
# The line equation is:
# \[
# y = mx + b
# \]
# We already know \( m = -1.5 \), so:
# \[
# y = -1.5x + b
# \]
#
# ---
#
# ### 4. **Find \( b \) (the \( y \)-intercept)**
# To find \( b \), use one of the points. Let’s use \( B(0, 3) \), where \( x = 0 \) and \( y = 3 \):
# \[
# 3 = -1.5(0) + b
# \]
# \[
# b = 3
# \]
#
# ---
#
# ### 5. **Write the final equation**
# Now we know \( m = -1.5 \) and \( b = 3 \):
# \[
# y = -1.5x + 3
# \]
#
# ---
#
# ### **Final Answer**
# The equation of the line through \( A(2, 0) \) and \( B(0, 3) \) is:
# \[
# y = -1.5x + 3
# \]
#
# [GeoGebra](https://app.gemoo.com/share/image-annotation/739326329650548736?codeId=vzAOZrpRGgZ00&origin=imageurlgenerator&card=739326327989604352)

# %% [markdown]
# ### Explanation
#
# 1. **Slope of the line**:
#    The equation \(y = x + 3\) is in the slope-intercept form \(y = mx + b\), where \(m\) is the slope.
#    Here, \(m = 1\).
#
# 2. **Angle formula**:
#    The angle \(\theta\) between a line and the \(Ox\)-axis is calculated using the formula:
#    $$\tan(\theta) = m$$
#    Substituting \(m = 1\):
#    $$\tan(\theta) = 1$$
#
# 3. **Find \(\theta\)**:
#    To get the angle:
#    $$\theta = \arctan(1)$$
#    From trigonometry, \(\arctan(1) = 45^\circ\).
#
# ---
#
# ### Final Answer
#
# The angle between the line \(y = x + 3\) and the \(Ox\)-axis is:
# $$\theta = 45^\circ$$
#
# [Geogebra](https://app.gemoo.com/share/image-annotation/740965069867397120?codeId=v6jZoVdy8oR1z&origin=imageurlgenerator&card=740965067988336640)

# %% [markdown]
# ### Problem:
# Find a vector perpendicular to the line \( x + y + 1 = 0 \).
#
# ---
#
# ### Step 1: Understand the Line Equation
# The given line is:
# $$
# x + y + 1 = 0
# $$
#
# This is in the standard form of a line:
# $$
# Ax + By + C = 0
# $$
# where:
# - \( A = 1 \)
# - \( B = 1 \)
# - \( C = 1 \)
#
# ---
#
# ### Step 2: Find the Normal Vector
# The coefficients \( A \) and \( B \) in the standard form of a line give us a vector that is **perpendicular** (normal) to the line. This vector is:
# $$
# \vec{n} = (A, B) = (1, 1)
# $$
#
# ---
#
# ### Step 3: Verify Perpendicularity
# To confirm that \( \vec{n} = (1, 1) \) is perpendicular to the line, we can check the **dot product** with the direction vector of the line.
#
# 1. **Direction Vector of the Line**:
#    Rewrite the line \( x + y + 1 = 0 \) in slope-intercept form:
#    $$
#    y = -x - 1
#    $$
#    The slope of the line is \( -1 \), so the direction vector \( \vec{d} \) of the line is:
#    $$
#    \vec{d} = (1, -1)
#    $$
#
# 2. **Dot Product**:
#    The dot product of \( \vec{n} \) and \( \vec{d} \) is:
#    $$
#    \vec{n} \cdot \vec{d} = (1)(1) + (1)(-1) = 1 - 1 = 0
#    $$
#    Since the dot product is \( 0 \), the vectors are perpendicular.
#
# ---
#
# ### Final Answer:
# A vector perpendicular to the line \( x + y + 1 = 0 \) is:
# $$
# \vec{n} = (1, 1)
# $$
#
# ---
#
# ### Extra Notes:
# - Any vector that is a multiple of \( \vec{n} = (1, 1) \) is also perpendicular to the line. For example:
#   - \( \vec{n} = (2, 2) \)
#   - \( \vec{n} = (-1, -1) \)
#
# [Geogebra](https://app.gemoo.com/share/image-annotation/740966635861118976?codeId=Pa0OQjoBykxVG&origin=imageurlgenerator&card=740966634158231552)
